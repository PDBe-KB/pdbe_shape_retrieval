# %%
import csv
import os
import numpy as np
from matplotlib import pyplot as plt

# %%
WKS_csv_files_path = ''
list_entries = ''
output_path = ' '
entry_labels = list_entries.read().splitlines()

for entry in entry_labels: 
    file_name = '{}_WKS.csv'.format(entry)
    file_WKS = os.path.join(WKS_csv_files_path,file_name)
    if os.path.exists(file_WKS):        
        with open(file_WKS) as csvfile:
           WKS = list(csv.reader(csvfile))
           WKS = np.asarray(FM, dtype=float)
           style = {'facecolor': 'none', 'edgecolor': 'C0', 'linewidth': 3}
           plt.hist(descr1, bins=50,**style)
           plt.xlabel("WKS descriptors")
           plt.ylabel("Frequency")
           fig_out = os.path.join(output_path,'{}_hist_WKS.png'.format(entry))
           plt.savefig(fig_out)
           plt. close()
